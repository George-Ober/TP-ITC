# %%
from numpy import *
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5, 6, 6.5, 6.7, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5, 11.0, 11.5, 12.0, 12.5, 13.0, 13.4, 13.6, 13.8, 14.0, 14.5, 15.0]

y = [2.89, 3.14, 3.43, 3.7, 3.9, 4.05, 4.22, 4.30, 4.34, 4.37, 4.46, 4.5, 4.6, 4.7, 4.77, 4.87, 4.95, 5.08, 5.21, 5.34, 5.6, 5.87, 6.9, 7.1, 9.73, 10.33, 10.8, 11.06]

plt.plot(x, y, color = 'green',
         marker = '+', markeredgewidth = 2,
         markersize = 8, markeredgecolor = 'black')

plt.title('Dosage\n')
plt.xlabel('$v$')
plt.ylabel('$pH = - \\log \\frac{[H_3 O ^+]}{c_0}$')
plt.grid()

plt.show()
